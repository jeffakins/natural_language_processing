# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
def parse_news_article(article):
    title = article.h2.text
    date, author = article.select('.italic')[0].find_all('p')
    return {'title': title, 'date': date.text, 'author': author.text}

# %%
response = requests.get('https://web-scraping-demo.zgulde.net/news')
soup = BeautifulSoup(response.text)
articles = soup.select('.grid.gap-y-12 > div')
pd.DataFrame([parse_news_article(article) for article in articles])
# Out:
#                           title          date                  author
# 0     technology concern little   2018-12-27           By Jason Lang
# 1             improve sound sit   1977-12-06        By David Bennett
# 2       difference if candidate   1979-06-26       By Jason Schaefer
# 3              close color show   1983-05-03        By Brian Vasquez
# 4          fly material college   2013-04-02       By Jennifer Novak
# 5   increase successful involve   2016-02-29        By Alicia Gibson
# 6               head herself in   1989-01-20         By Diana Powers
# 7               scene star your   1981-05-16         By Andres Banks
# 8       everything enter threat   1992-11-16    By Timothy Myers DDS
# 9              rather visit boy   1994-07-16     By Patricia Bennett
# 10           stock source power   2006-12-21         By Kevin Walker
# 11       tough clearly decision   1996-11-10   By Mr. Manuel Morales
